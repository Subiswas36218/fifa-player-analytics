# %% [markdown]
# # Notebook 01 — Dataset Overview
#
# Load and inspect the FIFA dataset.

# %%
from pathlib import Path
import sys

# Find the project root (the directory containing "src")
PROJECT_ROOT = Path.cwd().parent

# Add project root to Python path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: /Users/subhankarbiswas/fifa-player-analytics

# %%
from src.config import RAW_DATASET
from src.data_loader import DataLoader

loader = DataLoader(RAW_DATASET)
df = loader.load()
# Out:
# [2026-07-19 02:55:30,499] INFO - fifa_player_analytics - Loading dataset: /Users/subhankarbiswas/fifa-player-analytics/data/raw/players.csv
# /Users/subhankarbiswas/fifa-player-analytics/src/utils.py:72: DtypeWarning: Columns (0: gk) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path, **kwargs)
# [2026-07-19 02:58:09,611] INFO - fifa_player_analytics - read_csv finished in 159.106s
# [2026-07-19 02:58:33,216] INFO - fifa_player_analytics - Loaded 10003590 rows and 110 columns

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (10003590, 110)
# ...

# %%
loader.metadata(df)
# Out:
# DatasetMetadata(rows=10003590, columns=110, memory_mb=np.float64(8191.15), duplicate_rows=0)

# %%
report = loader.quality_report(df)
report["missing"].head()
# Out:
#                       missing  percentage
# nation_jersey_number  9410000       94.07
# nation_team_id        9410000       94.07
# nation_position       9410000       94.07
# club_loaned_from      9299422       92.96
# player_tags           9238676       92.35

# %%
df.describe(include="all").T
# Out:
#                        count    unique  \
# player_id         10003590.0       NaN
# player_url          10003590  10003590
# fifa_version      10003590.0       NaN
# fifa_update       10003590.0       NaN
# fifa_update_date    10003590       553
# ...                      ...       ...
# cb                  10003590       525
# rcb                 10003590       525
# rb                  10003590       440
# gk                  10003590       334
# player_face_url     10003590    196931
#
#                                                                 top    freq  \
# player_id                                                       NaN     NaN
# player_url                       /player/158023/lionel-messi/230009       1
# fifa_version                                                    NaN     NaN
# fifa_update                                                     NaN     NaN
# fifa_update_date                                         2021-09-25   37497
# ...

# %% [markdown]
# Continue with Notebook 02 for preprocessing.
